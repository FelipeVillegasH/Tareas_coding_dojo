# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeVillegasH/Tareas_coding_dojo/blob/main/Organize_Data_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Organize Data Homework Coding Dojo Core
# # By Felipe Villegas
# ### Created: 15.01.2022
# ##### Description: Import df with irregular column numbers/ "columns expected error" and use of the method .melt

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gdpdf=pd.read_csv('/content/drive/MyDrive/CodingDojo/tareas/core/Semana 2 Pandas/GDP.csv',skiprows=4)
# the import error was due to the previews titles in the df which were not consistent with the number of columns of the df
# therefore we skip them in order to be able to import the df with its consistent shape defined by the number of columns

# %%
gdpdf.head()
# Out:
#   Country Name Country Code  ...          2017 Unnamed: 62
# 0        Aruba          ABW  ...           NaN         NaN
# 1  Afghanistan          AFG  ...  2.081530e+10         NaN
# 2       Angola          AGO  ...  1.242094e+11         NaN
# 3      Albania          ALB  ...  1.303935e+10         NaN
# 4      Andorra          AND  ...  3.012914e+09         NaN
#
# [5 rows x 63 columns]

# %%
gdpdf.info()
# since there are no values in the Unnamed 62 column we proceed to delete it
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            133 non-null    float64
#  5   1961            133 non-null    float64
#  6   1962            135 non-null    float64
#  7   1963            135 non-null    float64
#  8   1964            135 non-null    float64
#  9   1965            145 non-null    float64
#  10  1966            146 non-null    float64
#  11  1967            149 non-null    float64
#  12  1968            153 non-null    float64
#  13  1969            153 non-null    float64
#  14  1970            162 non-null    float64
#  15  1971            163 non-null    float64
#  16  1972            163 non-null    float64
# ...

# %%
gdpdf = gdpdf.drop(columns=['Unnamed: 62'])

# %%
# we confirm if the column was deleted succesfully:
gdpdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 62 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    264 non-null    object
#  2   Indicator Name  264 non-null    object
#  3   Indicator Code  264 non-null    object
#  4   1960            133 non-null    float64
#  5   1961            133 non-null    float64
#  6   1962            135 non-null    float64
#  7   1963            135 non-null    float64
#  8   1964            135 non-null    float64
#  9   1965            145 non-null    float64
#  10  1966            146 non-null    float64
#  11  1967            149 non-null    float64
#  12  1968            153 non-null    float64
#  13  1969            153 non-null    float64
#  14  1970            162 non-null    float64
#  15  1971            163 non-null    float64
#  16  1972            163 non-null    float64
# ...

# %%
gdpdf1=gdpdf.melt(id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'],value_vars=['1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984','1985','1986','1987','1988','1989','1990','1991','1992','1993','1994','1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017'], var_name='Year',value_name='GDP')
gdpdf1
# Finally we use .melt to pivot the year columns and its values into rows
# Out:
#        Country Name Country Code  ...  Year           GDP
# 0             Aruba          ABW  ...  1960           NaN
# 1       Afghanistan          AFG  ...  1960  5.377778e+08
# 2            Angola          AGO  ...  1960           NaN
# 3           Albania          ALB  ...  1960           NaN
# 4           Andorra          AND  ...  1960           NaN
# ...             ...          ...  ...   ...           ...
# 15307        Kosovo          XKX  ...  2017  7.128691e+09
# 15308   Yemen, Rep.          YEM  ...  2017           NaN
# 15309  South Africa          ZAF  ...  2017  3.494193e+11
# 15310        Zambia          ZMB  ...  2017  2.580867e+10
# 15311      Zimbabwe          ZWE  ...  2017  1.784582e+10
#
# [15312 rows x 6 columns]

# %%
gdpdfsumary=gdpdf1.loc[:,['Country Name','Country Code','Year','GDP']]
gdpdfsumary
# and with the .loc method we locate the columns wanted
# Out:
#        Country Name Country Code  Year           GDP
# 0             Aruba          ABW  1960           NaN
# 1       Afghanistan          AFG  1960  5.377778e+08
# 2            Angola          AGO  1960           NaN
# 3           Albania          ALB  1960           NaN
# 4           Andorra          AND  1960           NaN
# ...             ...          ...   ...           ...
# 15307        Kosovo          XKX  2017  7.128691e+09
# 15308   Yemen, Rep.          YEM  2017           NaN
# 15309  South Africa          ZAF  2017  3.494193e+11
# 15310        Zambia          ZMB  2017  2.580867e+10
# 15311      Zimbabwe          ZWE  2017  1.784582e+10
#
# [15312 rows x 4 columns]
